# %% [markdown]
# # **Income Census Dataset: Initial Exploration**

# %%
#import ncessary libraries
import pandas as pd
import numpy as np

# %%
# raw data file path
file_path = "../income_dataset/"

# %%
# declare the column names test and train files dont have headers.
columns = [
    "age",
    "workclass",
    "fnlwgt",
    "education",
    "education-num",
    "marital-status",
    "occupation",
    "relationship",
    "race",
    "sex",
    "capital-gain",
    "capital-loss",
    "hours-per-week",
    "native-country",
    "income"
]

# load the data
df_train = pd.read_csv(file_path + "adult.data", header=None, names=columns, sep=",",skipinitialspace=True)
df_test = pd.read_csv(file_path + "adult.test", header=None, names=columns, sep=",", skipinitialspace=True, skiprows=1)

# %%
df_train.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income
# ...

# %% [markdown]
# # Explore few rows

# %%
df_train.sample()
# Out:
#       age workclass  fnlwgt     education  education-num      marital-status  \
# 3375   21   Private  305874  Some-college             10  Married-civ-spouse
#
#         occupation relationship   race   sex  capital-gain  capital-loss  \
# 3375  Craft-repair      Husband  White  Male             0             0
#
#       hours-per-week native-country income
# 3375              54  United-States  <=50K

# %%
# get any 2 sample rows
df_train.sample(2, random_state=42)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 14160   27    Private  160178  Some-college             10
# 27048   45  State-gov   50567       HS-grad              9
#
#            marital-status       occupation   relationship   race     sex  \
# 14160            Divorced     Adm-clerical  Not-in-family  White  Female
# 27048  Married-civ-spouse  Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 14160             0             0              38  United-States  <=50K
# 27048             0             0              40  United-States  <=50K

# %% [markdown]
# # Explore columns and data types

# %%
#check no of rows and columns
print(f"Train : {df_train.shape}  Test : {df_test.shape}")
# Out:
# Train : (32561, 15)  Test : (16281, 15)

# %%
#check datatypes
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df_test.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %% [markdown]
# # check for missing values for both test and train data
#  - check missing values using isna() and isnull(). Both fucntions checks same type of missing data
#  - check for ? as missing values are represented with ? as per the data document.

# %%
df_train.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# check for missing ? counts
(df_train == "?").sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
# get the missing(?) columns for train data
missing_q = (df_train == "?").sum()
missing_q[missing_q > 0].sort_values(ascending=False)
# Out:
# occupation        1843
# workclass         1836
# native-country     583
# dtype: int64

# %%
# get the missing(?) columns for test data
missing_t = (df_test == "?").sum()
missing_t[missing_t > 0].sort_values(ascending=False)
# Out:
# occupation        966
# workclass         963
# native-country    274
# dtype: int64

# %%
# view the missing values rows 
df_train[df_train.isin(["?"]).any(axis=1)].sample(2)
# Out:
#        age workclass  fnlwgt  education  education-num         marital-status  \
# 28194   27         ?  133359  Bachelors             13  Married-spouse-absent
# 30822   21         ?  105312    HS-grad              9          Never-married
#
#       occupation   relationship   race     sex  capital-gain  capital-loss  \
# 28194          ?  Not-in-family  White    Male             0             0
# 30822          ?  Not-in-family  White  Female             0             0
#
#        hours-per-week native-country income
# 28194              50              ?  <=50K
# 30822              20  United-States  <=50K

# %% [markdown]
# # statistical summary of train and test data

# %%
df_train.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# ...

# %%
df_test.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   16281.000000     16281  1.628100e+04     16281   16281.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     11210           NaN      5283            NaN
# mean       38.767459       NaN  1.894357e+05       NaN      10.072907
# std        13.849187       NaN  1.057149e+05       NaN       2.567545
# min        17.000000       NaN  1.349200e+04       NaN       1.000000
# 25%        28.000000       NaN  1.167360e+05       NaN       9.000000
# 50%        37.000000       NaN  1.778310e+05       NaN      10.000000
# 75%        48.000000       NaN  2.383840e+05       NaN      12.000000
# max        90.000000       NaN  1.490400e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# ...

# %%
# count of unique values per column in both train and test data
pd.DataFrame({
    'train_nunique': df_train.nunique(),
    'test_nunique': df_test.nunique()
})
# Out:
#                 train_nunique  test_nunique
# age                        73            73
# workclass                   9             9
# fnlwgt                  21648         12787
# education                  16            16
# education-num              16            16
# marital-status              7             7
# occupation                 15            15
# relationship                6             6
# race                        5             5
# sex                         2             2
# capital-gain              119           113
# capital-loss               92            82
# hours-per-week             94            89
# native-country             42            41
# income                      2             2

# %%
# check data distribution for numeric features
pd.DataFrame({
    "train_skew" : df_train.select_dtypes(include='number').skew(),
    "test_skew" : df_test.select_dtypes(include='number').skew()
})
#df_train.select_dtypes(include='number').skew()
# Out:
#                 train_skew  test_skew
# age               0.558743   0.554579
# fnlwgt            1.446980   1.422954
# education-num    -0.311676  -0.326338
# capital-gain     11.953848  11.778293
# capital-loss      4.594629   4.520647
# hours-per-week    0.227643   0.260419

# %% [markdown]
# #### Skewness
# - Skewness helps us understand the asymmetry of each numeric feature's distribution.
# - A value close to 0 indicates a roughly symmetric distribution
# - positive values show a right‑skew (long right tail)
# - negative values show a left‑skew.

# %% [markdown]
# # check for Duplicates in train and test data

# %%
df_train.duplicated().sum()
# Out:
# 24

# %%
df_train[df_train.duplicated()].sample(2)
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 30845   46   Private  133616  Some-college             10            Divorced
# 17040   46   Private  173243       HS-grad              9  Married-civ-spouse
#
#          occupation relationship   race     sex  capital-gain  capital-loss  \
# 30845  Adm-clerical    Unmarried  White  Female             0             0
# 17040  Craft-repair      Husband  White    Male             0             0
#
#        hours-per-week native-country income
# 30845              40  United-States  <=50K
# 17040              40  United-States  <=50K

# %%
df_test.duplicated().sum()
# Out:
# 5

# %%
df_test[df_test.duplicated()].sample(2)
# Out:
#        age     workclass  fnlwgt  education  education-num marital-status  \
# 11212   29       Private   36440  Bachelors             13  Never-married
# 15960   18  Self-emp-inc  378036       12th              8  Never-married
#
#             occupation   relationship   race     sex  capital-gain  \
# 11212     Adm-clerical  Not-in-family  White  Female             0
# 15960  Farming-fishing      Own-child  White    Male             0
#
#        capital-loss  hours-per-week native-country  income
# 11212             0              40  United-States  <=50K.
# 15960             0              10  United-States  <=50K.

# %% [markdown]
# ---

# %% [markdown]
# # **Summary of Initial Exploration**
# Train Data : - The dataset has 32,561 rows and 15 columns, containing both numeric and categorical features.
# - The categorical columns workclass, occupation, and native‑country contain "?" values that represent missing data.
# - There are 24 duplicate rows in the dataset.
# - Numeric features are mostly well‑distributed, except capital-gain and capital-loss, which are highly skewed.
#
#
# Test Data : The test dataset contains 16,281 rows and 15 columns, with the same numeric and categorical structure as the training data.
# - The first row is not valid data and should be skipped before analysis
# - The categorical columns workclass, occupation, and native‑country contain "?" values that represent missing data.
# - There are 5 duplicate rows in the dataset.
# - Numeric features follow similar patterns to the train set, with capital-gain and capital-loss remaining highly skewed.

# %% [markdown]
# # End of Initial Exploration
